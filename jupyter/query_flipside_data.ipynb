# %%
import hyperline
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# Snowflake syntax for flipside data source
sql = """ SELECT * FROM ethereum.uniswapv3.ez_lp_actions LIMIT 10 """
df = hyperline.sql.execute_flipside_sql(sql)

# %%
df
# Out:
#   BLOCKCHAIN  BLOCK_NUMBER     BLOCK_TIMESTAMP  \
# 0   ethereum      19555858 2024-03-31 19:11:23
# 1   ethereum      19556352 2024-03-31 20:50:59
# 2   ethereum      19555942 2024-03-31 19:28:35
# 3   ethereum      19556109 2024-03-31 20:02:11
# 4   ethereum      19556119 2024-03-31 20:04:11
# 5   ethereum      19556912 2024-03-31 22:44:11
# 6   ethereum      19556472 2024-03-31 21:15:35
# 7   ethereum      19556425 2024-03-31 21:05:47
# 8   ethereum      19556749 2024-03-31 22:11:11
# 9   ethereum      19556736 2024-03-31 22:08:35
#
#                                                               TX_HASH  \
# 0  0xac3246e16cc514e4369dea556ef9d4ffccf94cfff9de0a82132cff4bf5932872
# 1  0x9ebf905ad1356db22f9a21d797774a11712edbeb14f8178fe686cd329354ae03
# 2  0x5ece30ccaabd473ef303f99a7bffa7623177e03d75fc654a2033253bb19b8de2
# 3  0x58be38fa542d68dbc848a169c1557d663f24266966a2643cd330a10a2c69be23
# 4  0xbc4b3b2b76c188972d7711a2c85ec3b91f4e15a8bce8348651252c2d6e9b6366
# ...
